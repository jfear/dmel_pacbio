# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
def parse(fname):
    df = pd.read_csv(fname, sep='\t', index_col=0)
    #slice = (df.associated_gene.str.contains('novel') & ~df.associated_gene.str.contains('FBgn')).values
    slice = df.associated_gene.str.contains('novel').values
    return df[slice]

# %%
testis = parse('../output/pacbio-wf/w1118_testi1/sqanti/w1118_testi1.collapsed_classification.txt').dropna(axis=1, how='all')

# %%
male = parse('../output/pacbio-wf/w1118_wmal1/sqanti/w1118_wmal1.collapsed_classification.txt').dropna(axis=1, how='all')

# %%
testis.shape, male.shape
# Out:
# ((59, 16), (84, 16))

# %%
testis
# Out:
#            chrom strand  length  exons structural_category  \
# isoform
# PB.1519.1  chr2L      +    1989      1          intergenic
# PB.3958.1  chr3R      -    1548      1           antisense
# PB.4119.4  chr3R      +    1011      2           antisense
# PB.4119.2  chr3R      +    1098      2           antisense
# PB.2618.1  chr3L      +    1302      1        genic_intron
# PB.1421.1  chr2L      -    3434      1           antisense
# PB.3261.1  chr3L      -    1154      1        genic_intron
# PB.1520.1  chr2R      +    1935      2          intergenic
# PB.3046.1  chr3L      -    1086      1           antisense
# PB.602.1    chrX      +    2314      1           antisense
# PB.1562.1  chr2R      +    1219      2        genic_intron
# PB.818.1   chr2L      +    2045      2        genic_intron
# PB.1530.1  chr2R      -    1347      1          intergenic
# PB.1629.1  chr2R      -    1398      2           antisense
# PB.197.1    chrX      +    2164      2           antisense
# PB.2988.2  chr3L      +     951      2          intergenic
# PB.2988.1  chr3L      +    1046      1          intergenic
# PB.2339.1  chr2R      +    1205      1           antisense
# PB.30.1     chrX      +    1057      1           antisense
# PB.3852.1  chr3R      +     974      1           antisense
# PB.561.1    chrX      +    3023      1          intergenic
# PB.23.1     chr4      -     998      1          intergenic
# PB.989.1   chr2L      +    1051      1        genic_intron
# PB.1665.1  chr2R      -     998      1        genic_intron
# PB.666.1    chrY      +    1661      4          intergenic
# PB.4031.1  chr3R      -    1258      1           antisense
# PB.523.1    chrX      -    1273      1           antisense
# PB.3477.1  chr3R      +    1217      2        genic_intron
# PB.3387.1  chr3R      -    1086      1          intergenic
# PB.4275.1  chr3R      +    1543      1        genic_intron
# PB.1780.1  chr2R      -    2072      1           antisense
# PB.4394.1  chr3R      -    1534      2           antisense
# PB.3262.1  chr3L      +    1152      1        genic_intron
# PB.3692.1  chr3R      +    1078      1          intergenic
# PB.3266.1  chr3R      -     497      1        genic_intron
# PB.2585.1  chr3L      -    1978      1           antisense
# PB.4276.1  chr3R      +    1186      2          intergenic
# PB.435.1    chrX      -    1274      1        genic_intron
# PB.3259.1  chr3L      -    1303      2          intergenic
# PB.4079.1  chr3R      +     942      1        genic_intron
# PB.738.1   chr2L      -    1459      2        genic_intron
# PB.2416.3  chr2R      -    1352      1          intergenic
# PB.3780.1  chr3R      +    1050      2          intergenic
# PB.110.1    chrX      -    3047      1        genic_intron
# PB.3284.1  chr3R      -     972      2           antisense
# PB.3909.1  chr3R      +    1009      3           antisense
# PB.774.1   chr2L      -    2055      2           antisense
# PB.1527.1  chr2R      -    1150      2        genic_intron
# PB.2746.1  chr3L      +    1217      1          intergenic
# PB.1523.1  chr2R      -    1330      1          intergenic
# PB.1449.2  chr2L      +    2137      2           antisense
# PB.671.1    chrY      -    3236      1          intergenic
# PB.1656.1  chr2R      +    1166      1           antisense
# PB.1771.1  chr2R      +    1115      1        genic_intron
# PB.2416.1  chr2R      -    1798      1          intergenic
# PB.2416.2  chr2R      -    1678      1          intergenic
# PB.1982.1  chr2R      +    1670      1        genic_intron
# PB.2827.1  chr3L      -    1182      1           antisense
# PB.24.1     chrX      +    1934      1          intergenic
#
#                     associated_gene associated_transcript subcategory  \
# isoform
# PB.1519.1              novelGene_27                 novel   mono-exon
# PB.3958.1  novelGene_FBgn0023097_AS                 novel   mono-exon
# PB.4119.4  novelGene_FBgn0039192_AS                 novel  multi-exon
# PB.4119.2  novelGene_FBgn0039192_AS                 novel  multi-exon
# PB.2618.1              novelGene_12                 novel   mono-exon
# PB.1421.1  novelGene_FBgn0010300_AS                 novel   mono-exon
# PB.3261.1              novelGene_31                 novel   mono-exon
# PB.1520.1               novelGene_2                 novel  multi-exon
# PB.3046.1  novelGene_FBgn0261565_AS                 novel   mono-exon
# PB.602.1   novelGene_FBgn0087008_AS                 novel   mono-exon
# PB.1562.1              novelGene_14                 novel  multi-exon
# PB.818.1                novelGene_7                 novel  multi-exon
# PB.1530.1              novelGene_13                 novel   mono-exon
# PB.1629.1  novelGene_FBgn0003317_AS                 novel  multi-exon
# PB.197.1   novelGene_FBgn0029837_AS                 novel  multi-exon
# PB.2988.2              novelGene_24                 novel  multi-exon
# PB.2988.1              novelGene_24                 novel   mono-exon
# PB.2339.1  novelGene_FBgn0034921_AS                 novel   mono-exon
# PB.30.1    novelGene_FBgn0025633_AS                 novel   mono-exon
# PB.3852.1  novelGene_FBgn0261885_AS                 novel   mono-exon
# PB.561.1               novelGene_26                 novel   mono-exon
# PB.23.1                 novelGene_4                 novel   mono-exon
# PB.989.1               novelGene_16                 novel   mono-exon
# PB.1665.1              novelGene_17                 novel   mono-exon
# PB.666.1                novelGene_3                 novel  multi-exon
# PB.4031.1  novelGene_FBgn0263863_AS                 novel   mono-exon
# PB.523.1   novelGene_FBgn0030817_AS                 novel   mono-exon
# PB.3477.1              novelGene_19                 novel  multi-exon
# PB.3387.1              novelGene_15                 novel   mono-exon
# PB.4275.1              novelGene_33                 novel   mono-exon
# PB.1780.1  novelGene_FBgn0024836_AS                 novel   mono-exon
# PB.4394.1  novelGene_FBgn0003870_AS                 novel  multi-exon
# PB.3262.1              novelGene_32                 novel   mono-exon
# PB.3692.1              novelGene_21                 novel   mono-exon
# PB.3266.1               novelGene_6                 novel   mono-exon
# PB.2585.1  novelGene_FBgn0035490_AS                 novel   mono-exon
# PB.4276.1              novelGene_34                 novel  multi-exon
# PB.435.1               novelGene_22                 novel   mono-exon
# PB.3259.1              novelGene_29                 novel  multi-exon
# PB.4079.1              novelGene_28                 novel   mono-exon
# PB.738.1                novelGene_5                 novel  multi-exon
# PB.2416.3              novelGene_30                 novel   mono-exon
# PB.3780.1              novelGene_23                 novel  multi-exon
# PB.110.1                novelGene_8                 novel   mono-exon
# PB.3284.1  novelGene_FBgn0037235_AS                 novel  multi-exon
# PB.3909.1  novelGene_FBgn0267975_AS                 novel  multi-exon
# PB.774.1   novelGene_FBgn0264672_AS                 novel  multi-exon
# PB.1527.1              novelGene_11                 novel  multi-exon
# PB.2746.1              novelGene_18                 novel   mono-exon
# PB.1523.1              novelGene_10                 novel   mono-exon
# PB.1449.2  novelGene_FBgn0032845_AS                 novel  multi-exon
# PB.671.1                novelGene_9                 novel   mono-exon
# PB.1656.1  novelGene_FBgn0263593_AS                 novel   mono-exon
# PB.1771.1              novelGene_20                 novel   mono-exon
# PB.2416.1              novelGene_30                 novel   mono-exon
# PB.2416.2              novelGene_30                 novel   mono-exon
# PB.1982.1              novelGene_25                 novel   mono-exon
# PB.2827.1  novelGene_FBgn0045770_AS                 novel   mono-exon
# PB.24.1                 novelGene_1                 novel   mono-exon
#
#            RTS_stage  all_canonical  min_cov_pos  n_indels_junc   bite  \
# isoform
# PB.1519.1      False      canonical          NaN            NaN  False
# PB.3958.1      False      canonical          NaN            NaN  False
# PB.4119.4      False  non_canonical        360.0            0.0  False
# PB.4119.2      False  non_canonical        485.0            0.0  False
# PB.2618.1      False      canonical          NaN            NaN  False
# PB.1421.1      False      canonical          NaN            NaN  False
# PB.3261.1      False      canonical          NaN            NaN  False
# PB.1520.1      False      canonical        278.0            0.0  False
# PB.3046.1      False      canonical          NaN            NaN  False
# PB.602.1       False      canonical          NaN            NaN  False
# PB.1562.1      False  non_canonical         34.0            0.0  False
# PB.818.1       False      canonical       1513.0            0.0  False
# PB.1530.1      False      canonical          NaN            NaN  False
# PB.1629.1      False      canonical        514.0            0.0  False
# PB.197.1       False      canonical       1961.0            0.0  False
# PB.2988.2      False      canonical        573.0            0.0  False
# PB.2988.1      False      canonical          NaN            NaN  False
# PB.2339.1      False      canonical          NaN            NaN  False
# PB.30.1        False      canonical          NaN            NaN  False
# PB.3852.1      False      canonical          NaN            NaN  False
# PB.561.1       False      canonical          NaN            NaN  False
# PB.23.1        False      canonical          NaN            NaN  False
# PB.989.1       False      canonical          NaN            NaN  False
# PB.1665.1      False      canonical          NaN            NaN  False
# PB.666.1        True  non_canonical        822.0            0.0  False
# PB.4031.1      False      canonical          NaN            NaN  False
# PB.523.1       False      canonical          NaN            NaN  False
# PB.3477.1      False  non_canonical        369.0            0.0  False
# PB.3387.1      False      canonical          NaN            NaN  False
# PB.4275.1      False      canonical          NaN            NaN  False
# PB.1780.1      False      canonical          NaN            NaN  False
# PB.4394.1      False      canonical         24.0            0.0  False
# PB.3262.1      False      canonical          NaN            NaN  False
# PB.3692.1      False      canonical          NaN            NaN  False
# PB.3266.1      False      canonical          NaN            NaN  False
# PB.2585.1      False      canonical          NaN            NaN  False
# PB.4276.1      False      canonical        410.0            0.0  False
# PB.435.1       False      canonical          NaN            NaN  False
# PB.3259.1      False      canonical         68.0            0.0  False
# PB.4079.1      False      canonical          NaN            NaN  False
# PB.738.1       False      canonical        451.0            0.0  False
# PB.2416.3      False      canonical          NaN            NaN  False
# PB.3780.1      False      canonical         71.0            0.0  False
# PB.110.1       False      canonical          NaN            NaN  False
# PB.3284.1      False  non_canonical         50.0            0.0  False
# PB.3909.1      False      canonical        480.0            0.0  False
# PB.774.1       False      canonical        499.0            0.0  False
# PB.1527.1      False  non_canonical        569.0            0.0  False
# PB.2746.1      False      canonical          NaN            NaN  False
# PB.1523.1      False      canonical          NaN            NaN  False
# PB.1449.2      False      canonical        649.0            0.0  False
# PB.671.1       False      canonical          NaN            NaN  False
# PB.1656.1      False      canonical          NaN            NaN  False
# PB.1771.1      False      canonical          NaN            NaN  False
# PB.2416.1      False      canonical          NaN            NaN  False
# PB.2416.2      False      canonical          NaN            NaN  False
# PB.1982.1      False      canonical          NaN            NaN  False
# PB.2827.1      False      canonical          NaN            NaN  False
# PB.24.1        False      canonical          NaN            NaN  False
#
#           FSM_class      coding  perc_A_downstream_TTS
# isoform
# PB.1519.1         A  non_coding                   65.0
# PB.3958.1         A  non_coding                   35.0
# PB.4119.4         B  non_coding                   20.0
# PB.4119.2         B  non_coding                   20.0
# PB.2618.1         A  non_coding                   40.0
# PB.1421.1         A  non_coding                   40.0
# PB.3261.1         A  non_coding                   35.0
# PB.1520.1         A  non_coding                   25.0
# PB.3046.1         A  non_coding                   35.0
# PB.602.1          A  non_coding                   30.0
# PB.1562.1         A  non_coding                   25.0
# PB.818.1          A  non_coding                   35.0
# PB.1530.1         A  non_coding                   45.0
# PB.1629.1         A  non_coding                   45.0
# PB.197.1          A  non_coding                   20.0
# PB.2988.2         B  non_coding                   15.0
# PB.2988.1         B  non_coding                   10.0
# PB.2339.1         A  non_coding                   40.0
# PB.30.1           A  non_coding                   35.0
# PB.3852.1         A  non_coding                   75.0
# PB.561.1          A  non_coding                   20.0
# PB.23.1           A  non_coding                   75.0
# PB.989.1          A  non_coding                   20.0
# PB.1665.1         A  non_coding                   30.0
# PB.666.1          A  non_coding                   30.0
# PB.4031.1         A  non_coding                   10.0
# PB.523.1          A  non_coding                   45.0
# PB.3477.1         A  non_coding                   20.0
# PB.3387.1         A  non_coding                   55.0
# PB.4275.1         A  non_coding                   45.0
# PB.1780.1         A  non_coding                   45.0
# PB.4394.1         A  non_coding                   30.0
# PB.3262.1         A  non_coding                   40.0
# PB.3692.1         A  non_coding                   30.0
# PB.3266.1         A  non_coding                   25.0
# PB.2585.1         A  non_coding                   60.0
# PB.4276.1         A  non_coding                   40.0
# PB.435.1          A  non_coding                   70.0
# PB.3259.1         A  non_coding                   10.0
# PB.4079.1         A  non_coding                   45.0
# PB.738.1          A  non_coding                    0.0
# PB.2416.3         B  non_coding                   50.0
# PB.3780.1         A  non_coding                   40.0
# PB.110.1          A  non_coding                   25.0
# PB.3284.1         A  non_coding                   35.0
# PB.3909.1         A  non_coding                   35.0
# PB.774.1          A  non_coding                   25.0
# PB.1527.1         A  non_coding                   40.0
# PB.2746.1         A  non_coding                   50.0
# PB.1523.1         A  non_coding                   30.0
# PB.1449.2         A  non_coding                   25.0
# PB.671.1          A  non_coding                   20.0
# PB.1656.1         A  non_coding                   30.0
# PB.1771.1         A  non_coding                   15.0
# PB.2416.1         B  non_coding                   20.0
# PB.2416.2         B  non_coding                   50.0
# PB.1982.1         A  non_coding                   25.0
# PB.2827.1         A  non_coding                   90.0
# PB.24.1           A  non_coding                   45.0

# %%
print('\n'.join(sorted(testis.index.values.tolist())))
# Out:
# PB.110.1
# PB.1421.1
# PB.1449.2
# PB.1519.1
# PB.1520.1
# PB.1523.1
# PB.1527.1
# PB.1530.1
# PB.1562.1
# PB.1629.1
# PB.1656.1
# PB.1665.1
# PB.1771.1
# PB.1780.1
# PB.197.1
# PB.1982.1
# PB.23.1
# PB.2339.1
# PB.24.1
# PB.2416.1
# PB.2416.2
# PB.2416.3
# PB.2585.1
# PB.2618.1
# PB.2746.1
# PB.2827.1
# PB.2988.1
# PB.2988.2
# PB.30.1
# PB.3046.1
# PB.3259.1
# PB.3261.1
# PB.3262.1
# PB.3266.1
# PB.3284.1
# PB.3387.1
# PB.3477.1
# PB.3692.1
# PB.3780.1
# PB.3852.1
# PB.3909.1
# PB.3958.1
# PB.4031.1
# PB.4079.1
# PB.4119.2
# PB.4119.4
# PB.4275.1
# PB.4276.1
# PB.435.1
# PB.4394.1
# PB.523.1
# PB.561.1
# PB.602.1
# PB.666.1
# PB.671.1
# PB.738.1
# PB.774.1
# PB.818.1
# PB.989.1
